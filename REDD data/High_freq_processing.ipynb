# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
path = 'high_freq/high_freq/house_3/current_1.dat'

df_ = pd.read_csv(path, sep=" ", header=None)
# data.columns = ["Time", "Cycles"]

# %%
data.rename(columns={0:'Time'}, inplace=True)
data.rename(columns={1:'Cycles'}, inplace=True)
data.head()
# Out:
#            Time  Cycles         2         3         4         5         6  \
# 0  1.302922e+09  1782.0 -0.017231 -0.017167 -0.017059 -0.017008 -0.017104
# 1  1.302922e+09  1782.0 -0.017288 -0.017300 -0.017320 -0.017308 -0.017248
# 2  1.302931e+09  2760.0  0.002427  0.007893  0.020264  0.037044  0.059954
# 3  1.302931e+09  2065.0  0.004701  0.008471  0.022125  0.040235  0.063376
# 4  1.302931e+09   206.0  0.002921  0.006746  0.021267  0.042351  0.065329
#
#           7         8         9    ...          267       268       269  \
# 0 -0.017163 -0.017450 -0.017587    ...    -0.017431 -0.017421 -0.017433
# 1 -0.017345 -0.017636 -0.017700    ...    -0.017539 -0.017615 -0.017604
# 2  0.139391  0.195261  0.231653    ...    -0.131324 -0.208694 -0.192772
# 3  0.143110  0.198713  0.237631    ...    -0.131911 -0.212030 -0.197415
# 4  0.144688  0.197718  0.238668    ...    -0.216036 -0.261511 -0.158430
#
#         270       271       272       273       274       275       276
# ...

# %%
data['timestamp'] = data['Time'].astype("datetime64[s]")
data = data.set_index(data['timestamp'].values)
data.head()
# Out:
#                              Time  Cycles         2         3         4  \
# 2011-04-16 02:51:20  1.302922e+09  1782.0 -0.017231 -0.017167 -0.017059
# 2011-04-16 02:51:49  1.302922e+09  1782.0 -0.017288 -0.017300 -0.017320
# 2011-04-16 05:11:26  1.302931e+09  2760.0  0.002427  0.007893  0.020264
# 2011-04-16 05:12:12  1.302931e+09  2065.0  0.004701  0.008471  0.022125
# 2011-04-16 05:12:46  1.302931e+09   206.0  0.002921  0.006746  0.021267
#
#                             5         6         7         8         9  \
# 2011-04-16 02:51:20 -0.017008 -0.017104 -0.017163 -0.017450 -0.017587
# 2011-04-16 02:51:49 -0.017308 -0.017248 -0.017345 -0.017636 -0.017700
# 2011-04-16 05:11:26  0.037044  0.059954  0.139391  0.195261  0.231653
# 2011-04-16 05:12:12  0.040235  0.063376  0.143110  0.198713  0.237631
# 2011-04-16 05:12:46  0.042351  0.065329  0.144688  0.197718  0.238668
#
#                             ...               268       269       270  \
# ...

# %%
data.drop(['Time'], axis=1, inplace=True)
data.head()
# Out:
#                      Cycles         2         3         4         5         6  \
# 2011-04-16 02:51:20  1782.0 -0.017231 -0.017167 -0.017059 -0.017008 -0.017104
# 2011-04-16 02:51:49  1782.0 -0.017288 -0.017300 -0.017320 -0.017308 -0.017248
# 2011-04-16 05:11:26  2760.0  0.002427  0.007893  0.020264  0.037044  0.059954
# 2011-04-16 05:12:12  2065.0  0.004701  0.008471  0.022125  0.040235  0.063376
# 2011-04-16 05:12:46   206.0  0.002921  0.006746  0.021267  0.042351  0.065329
#
#                             7         8         9        10  \
# 2011-04-16 02:51:20 -0.017163 -0.017450 -0.017587 -0.017528
# 2011-04-16 02:51:49 -0.017345 -0.017636 -0.017700 -0.017679
# 2011-04-16 05:11:26  0.139391  0.195261  0.231653  0.301852
# 2011-04-16 05:12:12  0.143110  0.198713  0.237631  0.309744
# 2011-04-16 05:12:46  0.144688  0.197718  0.238668  0.306374
#
#                             ...               268       269       270  \
# ...

# %%
path = 'high_freq/high_freq/house_3/current_1.dat'
df_h3_curr1 = pd.read_csv(path, sep=" ", header=None)
df_h3_curr1.rename(columns={0:'Time'}, inplace=True)
df_h3_curr1.rename(columns={1:'Cycles'}, inplace=True)
df_h3_curr1['timestamp'] = df_h3_curr1['Time'].astype("datetime64[s]")
df_h3_curr1 = df_h3_curr1.set_index(df_h3_curr1['timestamp'].values)
df_h3_curr1.drop(['Time'], axis=1, inplace=True)

path = 'high_freq/high_freq/house_3/current_2.dat'
df_h3_curr2 = pd.read_csv(path, sep=" ", header=None)
df_h3_curr2.rename(columns={0:'Time'}, inplace=True)
df_h3_curr2.rename(columns={1:'Cycles'}, inplace=True)
df_h3_curr2['timestamp'] = df_h3_curr2['Time'].astype("datetime64[s]")
df_h3_curr2 = df_h3_curr2.set_index(df_h3_curr2['timestamp'].values)
df_h3_curr2.drop(['Time'], axis=1, inplace=True)

path = 'high_freq/high_freq/house_3/voltage.dat'
df_h3_volt = pd.read_csv(path, sep=" ", header=None)
df_h3_volt.rename(columns={0:'Time'}, inplace=True)
df_h3_volt.rename(columns={1:'Cycles'}, inplace=True)
df_h3_volt['timestamp'] = df_h3_volt['Time'].astype("datetime64[s]")
df_h3_volt = df_h3_volt.set_index(df_h3_volt['timestamp'].values)
df_h3_volt.drop(['Time'], axis=1, inplace=True)

path = 'high_freq/high_freq/house_5/current_1.dat'
df_h5_curr1 = pd.read_csv(path, sep=" ", header=None)
df_h5_curr1.rename(columns={0:'Time'}, inplace=True)
df_h5_curr1.rename(columns={1:'Cycles'}, inplace=True)
df_h5_curr1['timestamp'] = df_h5_curr1['Time'].astype("datetime64[s]")
df_h5_curr1 = df_h5_curr1.set_index(df_h5_curr1['timestamp'].values)
df_h5_curr1.drop(['Time'], axis=1, inplace=True)

path = 'high_freq/high_freq/house_5/current_2.dat'
df_h5_curr2 = pd.read_csv(path, sep=" ", header=None)
df_h5_curr2.rename(columns={0:'Time'}, inplace=True)
df_h5_curr2.rename(columns={1:'Cycles'}, inplace=True)
df_h5_curr2['timestamp'] = df_h5_curr2['Time'].astype("datetime64[s]")
df_h5_curr2 = df_h5_curr2.set_index(df_h5_curr2['timestamp'].values)
df_h5_curr2.drop(['Time'], axis=1, inplace=True)

path = 'high_freq/high_freq/house_5/voltage.dat'
df_h5_volt = pd.read_csv(path, sep=" ", header=None)
df_h5_volt.rename(columns={0:'Time'}, inplace=True)
df_h5_volt.rename(columns={1:'Cycles'}, inplace=True)
df_h5_volt['timestamp'] = df_h5_volt['Time'].astype("datetime64[s]")
df_h5_volt = df_h5_volt.set_index(df_h5_volt['timestamp'].values)
df_h5_volt.drop(['Time'], axis=1, inplace=True)

# %%
df_h3_curr2.head()
# Out:
#                      Cycles         2         3         4         5         6  \
# 2011-04-16 02:51:20  1782.0  0.013275  0.013257  0.013399  0.013447  0.013479
# 2011-04-16 02:51:49  1782.0  0.012948  0.013030  0.012970  0.013087  0.013138
# 2011-04-16 05:11:26  2760.0  0.010864  0.077678  0.134422  0.190032  0.240667
# 2011-04-16 05:12:12  5830.0  0.021219  0.085437  0.138456  0.192836  0.240279
# 2011-04-16 05:13:49  2187.0  0.027409  0.090737  0.142872  0.196044  0.242590
#
#                             7         8         9        10  \
# 2011-04-16 02:51:20  0.013486  0.013211  0.013200  0.013125
# 2011-04-16 02:51:49  0.013141  0.012844  0.012700  0.012762
# 2011-04-16 05:11:26  0.288123  0.330805  0.373830  0.409350
# 2011-04-16 05:12:12  0.286005  0.326347  0.367732  0.401137
# 2011-04-16 05:13:49  0.285997  0.326040  0.365007  0.396899
#
#                             ...               268       269       270  \
# ...
